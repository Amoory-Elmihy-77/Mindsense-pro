# %% [markdown]
# # MindSense AI - Colab Training Notebook
# This notebook is intended for training the SER model on Google Colab using a free T4 GPU.
# To get started, upload the entire project folder to your Google Drive, then open this file using Colab.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 2. Navigate to the project directory
# Modify the folder name if you named it differently in your Google Drive
import os
PROJECT_PATH = '/content/drive/MyDrive/voice_model'
os.chdir(PROJECT_PATH)
print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/voice_model

# %%
# 3. Install required packages
# !pip install -r requirements.txt

# %%
# 4. Download RAVDESS dataset from Kaggle (if not already present)
# Note: You must upload 'kaggle.json' inside the project folder for this to work.
import os
if not os.path.exists('./RAVDESS'):
    print('Downloading dataset...')
    # !pip install kaggle
    # !mkdir -p ~/.kaggle
    # !cp kaggle.json ~/.kaggle/
    # !chmod 600 ~/.kaggle/kaggle.json
    # !kaggle datasets download -d uwrfkaggler/ravdess-emotional-speech-audio
    # !unzip -q ravdess-emotional-speech-audio.zip -d ./RAVDESS
    # !rm ravdess-emotional-speech-audio.zip
    print('Dataset downloaded successfully!')
else:
    print('Dataset already exists, skipping download!')
# Out:
# ...
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/uwrfkaggler/ravdess-emotional-speech-audio
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 429M/429M [00:02<00:00, 216MB/s]
#
# Dataset downloaded successfully!

# %%
# 5. Start Training
# Note: Before running this, make sure your config.py is set to use 'facebook/wav2vec2-large-robust' for the highest accuracy.
# !python train.py --data_dir ./RAVDESS
# Out:
# ...
#   Speech Emotion Recognition — Full Training Pipeline
# ...
#   Device : cuda
#   GPU    : Tesla T4
# ...
# [RAVDESS] Successfully loaded 1344 files
# label
# happy      384
# sad        384
# angry      384
# neutral    192
#
# Train: 940 | Val: 202 | Test: 202
#
# [Processor] Loading from facebook/wav2vec2-base ...
# ...
#
# [Weights] {'neutral': 1.753731369972229, 'angry': 0.8736059665679932, 'happy': 0.8736059665679932, 'sad': 0.8768656849861145}
#
# [Model] Loading facebook/wav2vec2-base ...
# Loading weights: 100% 211/211 [00:00<00:00, 947.49it/s, Materializing param=wav2vec2.masked_spec_embed]
# Wav2Vec2ForSequenceClassification LOAD REPORT from: facebook/wav2vec2-base
# Key                          | Status     |
# -----------------------------+------------+-
# project_hid.weight           | UNEXPECTED |
# project_hid.bias             | UNEXPECTED |
# project_q.bias               | UNEXPECTED |
# quantizer.codevectors        | UNEXPECTED |
# quantizer.weight_proj.weight | UNEXPECTED |
# ...
